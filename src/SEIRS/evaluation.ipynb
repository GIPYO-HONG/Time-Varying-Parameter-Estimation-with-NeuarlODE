# %%
import os
from pathlib import Path

os.chdir(Path.cwd().parent)

# %%
from SEIRS.exp import exp as ex
import jax.numpy as jnp
import numpy as np

import equinox as eqx

# %%
model = ex.model
EX = ex.EX
steps = ex.steps

ts_eval = ex.ts_eval

exp_name = ex.exp_name
path = f"SEIRS/results/{exp_name}"
param_path = f"{path}/model_parameter/model_step_{steps:05d}.eqx"
loss_list = np.load(f"{path}/loss_list.npy")

EX.model = eqx.tree_deserialise_leaves(
    param_path,
    EX.model
)

# %%
EX.plotting(ts_eval, loss_list)
